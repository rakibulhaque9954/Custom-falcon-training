# %%
# !pip install transformers

# %%
from transformers import pipeline

# Load the Falcon model
falcon = pipeline("text-generation", model="microsoft/falcon-base")

# Generate text using the Falcon model
generated_text = falcon("Hello, how are you?")

# Print the generated text
print(generated_text)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:261, in hf_raise_for_status(response, endpoint_name)
#     260 try:
# --> 261     response.raise_for_status()
#     262 except HTTPError as e:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/microsoft/falcon-base/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
